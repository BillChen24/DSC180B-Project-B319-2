# %%
# %matplotlib inline
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt
import pandas
import cv2

# %%
#input: file names in jpg
#list of class
#list of camera domain
import numpy as np
from PIL import Image
img = Image.open("data/raw/sample/8698966c-21bc-11ea-a13a-137349068a90.jpg")
arr = np.array(img).astype(np.float64)/256

# %%
len(arr)
# Out:
# 448

# %%
len(arr[1])
# Out:
# 597

# %%
r = arr[:,:,0]
g = arr[:,:,1]
b = arr[:,:,2]

# %%
r
# Out:
# array([[0.99609375, 0.97265625, 0.98828125, ..., 0.32421875, 0.32421875,
#         0.328125  ],
#        [0.99609375, 0.98828125, 0.99609375, ..., 0.32421875, 0.3203125 ,
#         0.31640625],
#        [0.99609375, 0.99609375, 0.99609375, ..., 0.32421875, 0.3125    ,
#         0.30078125],
#        ...,
#        [0.36328125, 0.35546875, 0.33203125, ..., 0.171875  , 0.1484375 ,
#         0.125     ],
#        [0.40234375, 0.43359375, 0.40234375, ..., 0.19140625, 0.171875  ,
#         0.14453125],
#        [0.42578125, 0.484375  , 0.44921875, ..., 0.2109375 , 0.1875    ,
#         0.15625   ]])

# %%
plt.imshow(img)

# %% [markdown]
# color distrbution using hist

# %%
# load image
imageObj = cv2.imread("data/raw/sample/8698966c-21bc-11ea-a13a-137349068a90.jpg")
# to avoid grid lines
plt.axis("off")
plt.title("Original Image")
plt.imshow(cv2.cvtColor(imageObj, cv2.COLOR_BGR2RGB))
plt.show()

# Get RGB data from image
blue_color = cv2.calcHist([imageObj], [0], None, [256], [0, 256])
red_color = cv2.calcHist([imageObj], [1], None, [256], [0, 256])
green_color = cv2.calcHist([imageObj], [2], None, [256], [0, 256])

# Separate Histograms for each color
plt.subplot(3, 1, 1)
plt.title("histogram of Blue")
plt.hist(blue_color, color="blue")

plt.subplot(3, 1, 2)
plt.title("histogram of Green")
plt.hist(green_color, color="green")

plt.subplot(3, 1, 3)
plt.title("histogram of Red")
plt.hist(red_color, color="red")

# for clear view
plt.tight_layout()
plt.show()

# combined histogram
plt.title("Histogram of all RGB Colors")
plt.hist(blue_color, color="blue")
plt.hist(green_color, color="green")
plt.hist(red_color, color="red")
plt.show()

# %%
imageObj = cv2.imread("data/raw/sample/871352c6-21bc-11ea-a13a-137349068a90.jpg")
# to avoid grid lines
plt.axis("off")
plt.title("Original Image")
plt.imshow(cv2.cvtColor(imageObj, cv2.COLOR_BGR2RGB))
plt.show()

# Get RGB data from image
blue_color = cv2.calcHist([imageObj], [0], None, [256], [0, 256])
red_color = cv2.calcHist([imageObj], [1], None, [256], [0, 256])
green_color = cv2.calcHist([imageObj], [2], None, [256], [0, 256])

# Separate Histograms for each color
plt.subplot(3, 1, 1)
plt.title("histogram of Blue")
plt.hist(blue_color, color="blue")

plt.subplot(3, 1, 2)
plt.title("histogram of Green")
plt.hist(green_color, color="green")

plt.subplot(3, 1, 3)
plt.title("histogram of Red")
plt.hist(red_color, color="red")

# for clear view
plt.tight_layout()
plt.show()

# combined histogram
plt.title("Histogram of all RGB Colors")
plt.hist(blue_color, color="blue")
plt.hist(green_color, color="green")
plt.hist(red_color, color="red")
plt.show()

# %% [markdown]
# combine image

# %%
#mapped = list(zip(picname, class, domain))
#listA = [i for i in mapped if i[1] == 'yes']
#listN = [i for i in mapped if i[1] == 'no']
list_im = ["data/raw/sample/8698966c-21bc-11ea-a13a-137349068a90.jpg", "data/raw/sample/871352c6-21bc-11ea-a13a-137349068a90.jpg"]
imgs = [ Image.open(i) for i in list_im ]
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack([i.resize(min_shape) for i in imgs])
imgs_comb = Image.fromarray(imgs_comb)
imgs_comb.save('comba.jpg' )
plt.imshow(imgs_comb)

# %%
imageObj = cv2.imread('comba.jpg')
# to avoid grid lines
plt.axis("off")
plt.title("Original Image")
plt.imshow(cv2.cvtColor(imageObj, cv2.COLOR_BGR2RGB))
plt.show()

# Get RGB data from image
blue_color = cv2.calcHist([imageObj], [0], None, [256], [0, 256])
red_color = cv2.calcHist([imageObj], [1], None, [256], [0, 256])
green_color = cv2.calcHist([imageObj], [2], None, [256], [0, 256])

# Separate Histograms for each color
plt.subplot(3, 1, 1)
plt.title("histogram of Blue")
plt.hist(blue_color, color="blue")

plt.subplot(3, 1, 2)
plt.title("histogram of Green")
plt.hist(green_color, color="green")

plt.subplot(3, 1, 3)
plt.title("histogram of Red")
plt.hist(red_color, color="red")

# for clear view
plt.tight_layout()
plt.show()

# combined histogram
plt.title("Histogram of all RGB Colors")
plt.hist(blue_color, color="blue")
plt.hist(green_color, color="green")
plt.hist(red_color, color="red")
plt.show()

# %%
from src.rgb_visualization import plot_scatter

# %%
img_1.show()
plt.subplot(131)
plot_scatter('data/raw/sample/8698966c-21bc-11ea-a13a-137349068a90.jpg', "img_1", 'Red', 'Green')
plt.subplot(132)
plot_scatter('data/raw/sample/8698966c-21bc-11ea-a13a-137349068a90.jpg', "img_1", 'Red', 'Blue')
plt.subplot(133)
plot_scatter('data/raw/sample/8698966c-21bc-11ea-a13a-137349068a90.jpg', "img_1", 'Green', 'Blue')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=597x448 at 0x7F8C91A76D90>

# %%
img_2.show()
plt.subplot(131)
plot_scatter('data/raw/sample/871352c6-21bc-11ea-a13a-137349068a90.jpg', "img_2", 'Red', 'Green')
plt.subplot(132)
plot_scatter('data/raw/sample/871352c6-21bc-11ea-a13a-137349068a90.jpg', "img_2", 'Red', 'Blue')
plt.subplot(133)
plot_scatter('data/raw/sample/871352c6-21bc-11ea-a13a-137349068a90.jpg', "img_2", 'Green', 'Blue')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=796x448 at 0x7F8C91ADB7F0>

# %% [markdown]
# ### Meta Data Analysis

# %%
import pandas as pd
metadata=pd.read_csv('data/metadata.csv').iloc[:,1:]
category_series=pd.read_csv('data/categories.csv').iloc[:,1:].set_index('category_id')['name']

metadata['hour'] =(metadata['datetime'].str[11:13]).astype(int)

# %%
#location X species
loc_cate=metadata.groupby(['location','category_id'])['filename'].count()
loc_cate.reset_index().sort_values('filename')
# Out:
#       location  category_id  filename
# 1588       403          310         1
# 1626       410          114         1
# 1625       410           97         1
# 1607       406          299         1
# 1606       406          291         1
# ...        ...          ...       ...
# 1344       337            0      3437
# 1018       256            0      3762
# 1862       464            0      4009
# 2006       501           96      4518
# 1342       336            0      7597
#
# [2342 rows x 3 columns]

# %%
#Localtion the image taken
locations=metadata.groupby('location')['filename'].count()
plt.plot(locations)

# %%
#Localtion the image taken
cate=metadata.groupby('category_id')['filename'].count()
plt.scatter(list(cate.index),cate.values)

# %%
#Time the image taken
hours_of_image=metadata.groupby('hour')['filename'].count()
plt.plot(hours_of_image)

# %% [markdown]
# Clean Metadata csv to include existing (downloaded) images only

# %%
# Possible Data To Clean out the metadata for existing image:
#Get the id in meta
data_folderpath='data/raw/sample/train/'
exist_img=[]
for i in range(metadata.shape[0]):
    try:
        img = Image.open(data_folderpath+f'{metadata.iloc[i].filename}')
    except:
        #print('no')
        ...
    else:
        exist_img+=[i]

# %%
len(exist_img)
# Out:
# 1051

# %%
metadata_existimg=metadata.iloc[exist_img]
metadata_existimg
# Out:
#           split  location_remapped  location  sequence_remapped  \
# 56      id_test                  2         3               2157
# 279     id_test                 13        25              10341
# 491     id_test                 13        25              13480
# 522     id_test                 13        25              19060
# 855     id_test                 26        57               5980
# ...         ...                ...       ...                ...
# 201657      val                309       529              16134
# 201992      val                320       547               4821
# 202175      val                320       547               4839
# 202266      val                320       547               4848
# 202759      val                320       547               4898
#
#                                       seq_id    y  category_id  \
# 56      30049b88-7d42-11eb-8fb5-0242ac1c0002  146          372
# 279     302176ea-7d42-11eb-8fb5-0242ac1c0002   53          116
# ...
